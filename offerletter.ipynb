# %% [markdown]
# ##
# """Noida
#
#
#
# Dear Roopesh,
#
#
#
# Subject: Offer of Employment for the position of Python
#
#
#
# We are delighted to extend this formal offer of employment to you for the
# position of Python at our organization. Based on your qualifications and the
# skills you demonstrated during the recruitment process, we are confident that
# you will be a valuable addition to our team.
#
#
#
# As discussed, your expected date of joining is 12-2-3020. Your total
# compensation package will be 4000000, which includes all salary components as
# per the company’s policy. Further details regarding your compensation will be
# provided in your employment contract.
#
#
#
# We expect you to bring your best efforts to help the company achieve its goals,
# and we are committed to supporting your professional growth during your time
# with us.
#
#
#
# Please confirm your acceptance of this offer by sending an email to
# rkt@gmail.com at your earliest convenience. Should you have any queries
# regarding this offer, feel free to reach out to us.
#
#
#
# We look forward to having you onboard and are excited about the great things we
# can accomplish together.
#
#
#
# Sincerely,
#
#
#
# Sunil Kumar
#
# HR Manager """

# %% [markdown]
# # inputs from user:-
# 1. City
# 2. Name
# 3. post
# 4. Date of joining
# 5. package
# 6. gmail
# 7. hr name

# %%
city=input("enter city name")
name=input("enter name person")
post=input("enter post to declare")
date_of_joining=input("enter the date of joining")
package=int(input("enter the package amount"))
gmail=input("enter the gmail")
hr_name=input("enter the hr name")

s1=(f"{city}")
print(s1)
print()

s2=(f"Dear {name} ,")
print(s2)
print()

print("Subject: Offer of Employment for the position of Python")
print()

s3=(f"""We are delighted to extend this formal offer of employment to you for theposition
of {post} at our organization. Based on your qualifications and theskillsyou demonstrated 
during the recruitment process, we are confident thatyou will be avaluable addition to our team. """)
print(s3)
print()


s4=(f"""As discussed, your expected date of joining is {date_of_joining} . Your total
compensation package will be {package} , which includes all salary components as
per the company’s policy. Further details regarding your compensation will be
provided in your employment contract.""")
print(s4)
print()


s5=(f"""We expect you to bring your best efforts to help the company achieve its goals,
and we are committed to supporting your professional growth during your time
with us.""")
print(s5)
print()


s6=(f"""Please confirm your acceptance of this offer by sending an email to
{gmail} at your earliest convenience Should you have any queries
regarding this offer, feel free to reach out to us. """)
print(s6)
print()


print(" We look forward to having you onboard and are excited about the great things we ")
print()


print("Sincerely,")
print()


s7=(f" {hr_name} ")
print(s7)
print()

print("HR Manager")
print()
# Out:
# enter city name Noida
# enter name person omakshi Dager
# enter post to declare Data Analyst
# enter the date of joining 20Mar2026
# enter the package amount 40000
# enter the gmail oma@gmail.com
# enter the hr name Mohit Kumar
# Noida
#
# Dear omakshi Dager ,
#
# Subject: Offer of Employment for the position of Python
#
# We are delighted to extend this formal offer of employment to you for theposition
# of Data Analyst at our organization. Based on your qualifications and theskillsyou demonstrated
# during the recruitment process, we are confident thatyou will be avaluable addition to our team.
#
# As discussed, your expected date of joining is 20Mar2026 . Your total
# compensation package will be 40000 , which includes all salary components as
# per the company’s policy. Further details regarding your compensation will be
# provided in your employment contract.
#
# We expect you to bring your best efforts to help the company achieve its goals,
# ...
