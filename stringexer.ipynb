# %%
# Q1:-

# %%
string1="omakshi"
string2="dager"
print(string1+" "+string2)
# Out:
# omakshi dager

# %%
# Q2:-

# %%
# + is a operator and join() is a string function
s=['omakshi' , 'dager']
print(s)
print(" ".join(s))
# Out:
# ['omakshi', 'dager']
# omakshi dager

# %%
# Q3:-

# %%
s="python"
print(s[0])
# Out:
# p

# %%
# Q4:-

# %%
# len() function is used to find the length of string

string1="abcdef"
print(len(string1))
# Out:
# 6

# %%
# Q5:-

# %%
s="abhi"
rsult=s.upper()
print(rsult)
# Out:
# ABHI

# %%
# Q6:-

# %%
s="ABHI"
rsult=s.lower()
print(rsult)
# Out:
# abhi

# %%
# Q7:-

# %%
s="omakshi dager"
print(s)
rsult=s.replace("dager","choudhary")
print(rsult)
# Out:
# omakshi dager
# omakshi choudhary

# %%
# Q8:-

# %%
s="Hi python"
rsult=s.split()
print(rsult)
# Out:
# ['Hi', 'python']

# %%
# Q9:-

# %%
s="hi my name is omakshi"
print(s.startswith("hi"))
print(s.startswith("my"))
# Out:
# True
# False

# %%
# Q10:-

# %%
s="hi my name is dager"
print(s.endswith("dager"))
print(s.endswith("hi"))
# Out:
# True
# False

# %%
# Q11:-

# %%
s="    omakshi  "
print(s.strip())
# Out:
# omakshi

# %%
# Q12:-

# %%
s="hey python"
print(s.find("hey"))
# Out:
# 0

# %%
# Q13:-

# %%
s="hey i am harry"
rsult=s.count("a")
print(rsult)
# Out:
# 2

# %%
# Q14:-

# %%
s="python"
print(s.isalpha())
# Out:
# True

# %%
# Q15:-

# %%
s="123456"
print(s.isdigit())
# Out:
# True

# %%
# Q16:-

# %%
s="nitin"
rev=s[::-1]
print(rev==s, "Given string is palindrome")
# Out:
# True Given string is palindrome

# %%
# Q17:-

# %%
s="abhiraj"
print(s[::-1])
# Out:
# jarihba

# %%
# Q18:-

# %%
s="omakshi"
age=20
rsult=("hi {} your age is {}").format(s,age)
print(rsult)
# Out:
# hi omakshi your age is 20

# %%
# Q19:-

# %%
s="welcome to coder life"
print(s[11:15])
# Out:
# code

# %%
# Q20:-

# %%
s="omakshi dager"
print(s)
rsult=s.replace("dager","")
print(rsult)
# Out:
# omakshi dager
# omakshi
