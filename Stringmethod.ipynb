# %% [markdown]
# # Create All String Methods:-

# %%
name="python"
print(name.capitalize())
# Out:
# Python

# %%
# 1. string.capitalize()

# %%
name="omakshi"
print(name.capitalize())
# Out:
# Omakshi

# %%
# 2. string.lower()

# %%
name="Java"
print(name.lower())
# Out:
# java

# %%
# 3. string.upper

# %%
name="python"
print(name.upper())
# Out:
# PYTHON

# %%
# 4. string.find()

# %%
name="java script"
print(name.find("c"))
# Out:
# 6

# %%
# 5. string.count(substring,start,end)

# %%
string=" hello python ttttttt"
print(string.count("o"))
print(string.count("t",5,len(string)))
# Out:
# 2
# 8

# %%
# 6. string.startswith(prefix[,start[,end]])

# %%
string="python"
print(string.startswith("p"))
# Out:
# True

# %%
# 7. string.endswith(suffix[,start[,end]])

# %%
string="python"
print(string.endswith("n"))
# Out:
# True

# %%
# 8. string.index()

# %%
string="hi i am harry"
print(string.index("am"))
# Out:
# 5

# %%
# 9. sting.isalnum()

# %%
s1="ocds123"
s2="12523"
s3="sdwejbfc"
s4="hi kitty" # contain space.
print(s1.isalnum())
print(s2.isalnum())
print(s3.isalnum())
print(s4.isalnum())
# Out:
# True
# True
# True
# False

# %%
# 10. string.isalpha()

# %%
s="ansbdh"
s1="abc123"
print(s.isalpha())
print(s1.isalpha())
# Out:
# True
# False

# %%
# 11. string.isdecimal()

# %%
s="12344"
s1="123.45"
s2="123a321"
print(s.isdecimal())
print(s1.isdecimal())
print(s2.isdecimal())
# Out:
# True
# False
# False

# %%
# 12. string.isdigit()

# %%
s="12345"
s1="wsnjxjde"
print(s.isdigit())
print(s1.isdigit())
# Out:
# True
# False

# %%
# 13. string.join()

# %%
s=["oma","ksh","i"]
print("".join(s))
# Out:
# omakshi

# %%
# 14. string.title()

# %%
s="python programming language"
print(s.title())
# Out:
# Python Programming Language

# %%
# 15. string.swapcase()

# %%
s="hello PYTHON"
print(s.swapcase())
# Out:
# HELLO python

# %%
# 16. string.replace()

# %%
s="hello world"
print(s.replace("world","python"))
# Out:
# hello python

# %%
# 17. string.split()

# %%
s="appple,mango,banana,orange"
print(s.split(","))
# Out:
# ['appple', 'mango', 'banana', 'orange']

# %%
# 18. string.strip()

# %%
s="  python  "
print(s.strip())
# Out:
# python

# %%
# 19. string.formate()

# %%
name="omakshi"
age=20
print(f"My name is {name} and age is {age} ")
# Out:
# My name is omakshi and age is 20
